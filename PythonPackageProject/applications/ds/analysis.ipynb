# %% [markdown]
# ### Research and Testing by the Data Scientist

# %% [markdown]
# ##### interacting with the db using db developer's code

# %%
# !docker start etl
# Out:
# etl

# %%
# !docker  exec etl python example.py
# Out:
# Inserting movie data...
# Inserting data: {'movie_name': 'Hunger Games : The Ballad of Songbirds and Snakes', 'release_year': 2023, 'movie_duration': 157, 'movie_rating': 10000000000000000000000000000, 'movie_genre': 'dystopian'}
# Row inserted successfully.
# Exporting movies table to DataFrame...
#     movie_id  ... movie_genre
# 0          1  ...      Sci-Fi
# 1          2  ...       Crime
# 2          3  ...      Action
# 3          4  ...       Drama
# 4          5  ...      Comedy
# 5          6  ...      Sci-Fi
# 6          7  ...       Drama
# 7          8  ...      Sci-Fi
# 8          9  ...     Fantasy
# 9         10  ...       Drama
# 10        11  ...   dystopian
# 11        12  ...   dystopian
# 12        13  ...   dystopian
# 13        14  ...   dystopian
#
# [14 rows x 6 columns]

# %% [markdown]
# As you can see the data can be read from the db, before this I also added a new entry "The Hunger Games: The ballad of songbirds and snakes"

# %% [markdown]
# ![alt text](image.png)

# %% [markdown]
# ### Future Steps

# %% [markdown]
# ##### Customer segmentation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The main analysis of the customers who use our streaming application is going to be centered around customer value: the value the customer gives to the platform vs the value customers receive from the platform. There are 4 categories:
#
# - Lost Cause
# - Vulnerable Customers
# - Free Riders
# - Star Customers

# %% [markdown]
# We have different kinds of tables, such as customers, engagements, segments, subscriptions, etc., and by taking different types of information from them and doing analysis, we can divide customers into segments. For example, from customers table, we will examine account creation and update details, from subscription table assess subscription types (student, family, basic, premium), and analyze engagement data such as session duration, film views, and like status.
#
# For example : a person who uses premium account, uses premium subscription is streaming quite frequently and has a very reent last watching session, spends a lot of time inside the platform and likes a lot of movies can be easily classified as a star suctomer because
# - They bring us a lot of money
# - Based on their behavior inside the platform (the duration, recency,frequecy) hints us that the customer also enjoys their experince within our platform
#
#
# In the future teh goal is to have a tailored model for this context that will help segment customers based on these criteria. And then, as we have already tested that the data can be inserted in the DB tables, the results will be inserted in table customer_segment having custoer_id and segment_id, indicating the segment of the particular customer.
